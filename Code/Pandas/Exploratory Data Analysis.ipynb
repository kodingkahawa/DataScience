# %% [markdown]
# <h1>EXPLORATORY DATA ANALYSIS</h1>
# <h2>Introduction to DataFrames</h2>
# <p>A DataFrame is composed of three main parts:</p>
# <ol>
#     <li><b>Index - </b>This is the counter used to identify the position of a row or column</li>
#     <li><b>Features - </b>These are the columns in the DataFrame</li>
#     <li><b>Cells - </b>These are the main </li>
# </ol>
#
#
# <p></p>
# <ol>
#     <li></li>
#     <li></li>
#     <li></li>
# </ol>
#
#
# ## Importation of the data

# %%
import pandas as pd

# %% [markdown]
# The cell below is used to set the maximum number of columns and rows to each cell as forty

# %%
pd.set_option('max_columns', 40, 'max_rows', 40)

# %%
pwd
# Out:
# 'C:\\Users\\User\\Desktop\\Data Science\\Class Notes\\Code\\Code\\Pandas'

# %% [markdown]
# The cell below is used to import the dataset that will be used in the process of Exploratory Data Analysis:

# %%
df = pd.read_csv('../../Data/movie.csv')

# %% [markdown]
# <p>The <b>head()</b> function is used to load the first five rows of the data:</p>

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %% [markdown]
# The number of rows to be displayed can be changed in the parameter function as shown below:

# %%
df.head(3)
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
# 2  Color      Sam Mendes                   602.0     148.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
#
#       actor_1_name                               movie_title  num_voted_users  \
# ...

# %% [markdown]
# <p>The <b>tail()</b> function is used to display the last five rows in the dataset:</p>

# %%
df.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  \
# 4911                   637.0      NaN                  Comedy|Drama
# ...

# %% [markdown]
# The tail function can be used to capture the last elements of the cell

# %%
df.tail(3)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                 genres actor_1_name  \
# 4913                     0.0      NaN  Drama|Horror|Thriller  Eva Boehnke
# 4914                   946.0  10443.0   Comedy|Drama|Romance    Alan Ruck
# 4915                    86.0  85222.0            Documentary  John August
#
#                movie_title  num_voted_users  cast_total_facebook_likes  \
# ...

# %% [markdown]
# To get the number of rows and columns respectively:

# %%
df.shape
# Out:
# (4916, 28)

# %% [markdown]
# To get the total number of rows in the dataset:

# %%
df.shape[0]
# Out:
# 4916

# %% [markdown]
# To get the total number of columns in the dataset:

# %%
df.shape[1]
# Out:
# 28

# %%
print('The dataframe has '+ str(df.shape[0]) + ' rows')
print('The dataframe has '+ str(df.shape[1]) + ' columns')
# Out:
# The dataframe has 4916 rows
# The dataframe has 28 columns

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The <b>info()</b> function is used to obtain the column names, their available values count, data types and aggregation of data type distribution:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %% [markdown]
# ## Types of analysis
# <ol>
#     <li>Univariate analysis</li>
#     <li>Multivariate analysis</li>
# </ol>
# <p>In order to obtain the list of column names in a dataset, <b>columns</b> is used:</p>

# %%
df.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# The cell below is used to make a decision on the truth or false nature of the presence of a value in a cell of a dataframe:

# %%
df.isnull().head()
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  False          False                   False     False
# 1  False          False                   False     False
# 2  False          False                   False     False
# 3  False          False                   False     False
# 4   True          False                    True      True
#
#    director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                    False                   False         False
# 1                    False                   False         False
# 2                    False                   False         False
# 3                    False                   False         False
# 4                    False                    True         False
#
#    actor_1_facebook_likes  gross  genres  actor_1_name  movie_title  \
# 0                   False  False   False         False        False
# 1                   False  False   False         False        False
# ...

# %% [markdown]
# In order to obtain the total number of missing values in each column in a dataset, the following procedure is used:

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                102
# num_critic_for_reviews        49
# duration                      15
# director_facebook_likes      102
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        862
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                152
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               300
# budget                       484
# title_year                   106
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 326
# movie_facebook_likes           0
# dtype: int64

# %% [markdown]
# In order to obtain the total number of non-missing values in each column in a dataset, the following procedure is used:

# %%
df.notnull().sum()
# Out:
# color                        4897
# director_name                4814
# num_critic_for_reviews       4867
# duration                     4901
# director_facebook_likes      4814
# actor_3_facebook_likes       4893
# actor_2_name                 4903
# actor_1_facebook_likes       4909
# gross                        4054
# genres                       4916
# actor_1_name                 4909
# movie_title                  4916
# num_voted_users              4916
# cast_total_facebook_likes    4916
# actor_3_name                 4893
# facenumber_in_poster         4903
# plot_keywords                4764
# movie_imdb_link              4916
# num_user_for_reviews         4895
# language                     4904
# country                      4911
# content_rating               4616
# budget                       4432
# title_year                   4810
# actor_2_facebook_likes       4903
# imdb_score                   4916
# aspect_ratio                 4590
# ...

# %% [markdown]
# `dtypes` is used to identify the data types that are being used in each column:

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# The `value_counts` is used to aggregate the total number of data types for the columns:

# %%
df.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# dtype: int64

# %%
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df = pd.read_csv('../../Data/movie.csv',
                 index_col = 'director_name')

# %% [markdown]
# The cell below is used to obtain the index values in the dataset:

# %%
df.index
# Out:
# Index([    'James Cameron',    'Gore Verbinski',        'Sam Mendes',
#        'Christopher Nolan',       'Doug Walker',    'Andrew Stanton',
#                'Sam Raimi',      'Nathan Greno',       'Joss Whedon',
#              'David Yates',
#        ...
#            'Shane Carruth',  'Neill Dela Llana',  'Robert Rodriguez',
#          'Anthony Vallone',      'Edward Burns',       'Scott Smith',
#                        nan,  'Benjamin Roberds',       'Daniel Hsia',
#                 'Jon Gunn'],
#       dtype='object', name='director_name', length=4916)

# %% [markdown]
# The cell below is used to obtain the values in each row in the dataset:

# %%
df.values
# Out:
# array([['Color', 723.0, 178.0, ..., 7.9, 1.78, 33000],
#        ['Color', 302.0, 169.0, ..., 7.1, 2.35, 0],
#        ['Color', 602.0, 148.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 13.0, 76.0, ..., 6.3, nan, 16],
#        ['Color', 14.0, 100.0, ..., 6.3, 2.35, 660],
#        ['Color', 43.0, 90.0, ..., 6.6, 1.85, 456]], dtype=object)

# %% [markdown]
# The cell below is used to obtain the column names in the dataset:

# %%
df.columns
# Out:
# Index(['color', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
df.head()
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
# Doug Walker          NaN                     NaN       NaN
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# Sam Mendes                             0.0                   161.0
# Christopher Nolan                  22000.0                 23000.0
# Doug Walker                          131.0                     NaN
#
#                        actor_2_name  actor_1_facebook_likes        gross  \
# director_name
# James Cameron      Joel David Moore                  1000.0  760505847.0
# ...

# %%
df = pd.read_csv('../../Data/movie.csv')

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %% [markdown]
# The cell below is used to obtain the total number of unique values per column:

# %%
df.nunique()
# Out:
# color                           2
# director_name                2397
# num_critic_for_reviews        528
# duration                      191
# director_facebook_likes       435
# actor_3_facebook_likes        906
# actor_2_name                 3030
# actor_1_facebook_likes        877
# gross                        4033
# genres                        914
# actor_1_name                 2095
# movie_title                  4916
# num_voted_users              4750
# cast_total_facebook_likes    3960
# actor_3_name                 3519
# facenumber_in_poster           19
# plot_keywords                4756
# movie_imdb_link              4916
# num_user_for_reviews          954
# language                       47
# country                        65
# content_rating                 18
# budget                        438
# title_year                     91
# actor_2_facebook_likes        917
# imdb_score                     78
# aspect_ratio                   22
# ...

# %% [markdown]
# The cell below is used to obtain the total number of unique values per column ands sorts them in ascending order:

# %%
df.nunique().sort_values(ascending = True)
# Out:
# color                           2
# content_rating                 18
# facenumber_in_poster           19
# aspect_ratio                   22
# language                       47
# country                        65
# imdb_score                     78
# title_year                     91
# duration                      191
# director_facebook_likes       435
# budget                        438
# num_critic_for_reviews        528
# movie_facebook_likes          876
# actor_1_facebook_likes        877
# actor_3_facebook_likes        906
# genres                        914
# actor_2_facebook_likes        917
# num_user_for_reviews          954
# actor_1_name                 2095
# director_name                2397
# actor_2_name                 3030
# actor_3_name                 3519
# cast_total_facebook_likes    3960
# gross                        4033
# num_voted_users              4750
# plot_keywords                4756
# movie_title                  4916
# ...

# %% [markdown]
# The cell below is used to obtain the total number of unique values per column and sorts them in descending order:

# %%
df.nunique().sort_values(ascending = False)
# Out:
# movie_imdb_link              4916
# movie_title                  4916
# plot_keywords                4756
# num_voted_users              4750
# gross                        4033
# cast_total_facebook_likes    3960
# actor_3_name                 3519
# actor_2_name                 3030
# director_name                2397
# actor_1_name                 2095
# num_user_for_reviews          954
# actor_2_facebook_likes        917
# genres                        914
# actor_3_facebook_likes        906
# actor_1_facebook_likes        877
# movie_facebook_likes          876
# num_critic_for_reviews        528
# budget                        438
# director_facebook_likes       435
# duration                      191
# title_year                     91
# imdb_score                     78
# country                        65
# language                       47
# aspect_ratio                   22
# facenumber_in_poster           19
# content_rating                 18
# ...

# %%
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %% [markdown]
# The cell below is used to obtain the least five rows with the lowest IMDB score:

# %%
df.nsmallest(5, 'imdb_score')
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 2789  Color         Jon M. Chu                    84.0     115.0
# 1126  Color  Lawrence Kasanoff                    12.0      91.0
# 2240  Color    Jason Friedberg                   111.0      88.0
# 2266  Color          Bob Clark                    32.0      88.0
# 4498  Color      A. Raven Cruz                     3.0      97.0
#
#       director_facebook_likes  actor_3_facebook_likes   actor_2_name  \
# 2789                    209.0                    41.0  Sean Kingston
# 1126                     11.0                   500.0   Larry Miller
# 2240                     82.0                   329.0       Tony Cox
# 2266                     84.0                   177.0  Vanessa Angel
# 4498                      0.0                    94.0    Vanilla Ice
#
#       actor_1_facebook_likes       gross  \
# 2789                   569.0  73000942.0
# 1126                   719.0         NaN
# ...

# %% [markdown]
# The cell below is used to obtain the top five rows with the top IMDB score:

# %%
df.nlargest(5, 'imdb_score')
# Out:
#       color         director_name  num_critic_for_reviews  duration  \
# 2725  Color        John Blanchard                     NaN      65.0
# 1920  Color        Frank Darabont                   199.0     142.0
# 3402  Color  Francis Ford Coppola                   208.0     175.0
# 2779  Color                   NaN                    53.0      55.0
# 4312    NaN        John Stockwell                     2.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes     actor_2_name  \
# 2725                      0.0                   176.0    Andrea Martin
# 1920                      0.0                   461.0   Jeffrey DeMunn
# 3402                      0.0                  3000.0    Marlon Brando
# 2779                      NaN                     2.0  Olaf Lubaszenko
# 4312                    134.0                   354.0       T.J. Storm
#
#       actor_1_facebook_likes        gross       genres    actor_1_name  \
# ...
